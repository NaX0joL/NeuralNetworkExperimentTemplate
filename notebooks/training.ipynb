# %%
from core.experiment import Experiment

from core.datasets.data_module import DataModuleGetter
from core.datasets.config import DatasetConfig

from core.datasets.UCR_Anomaly_Detection.config import UCR_Anomaly_Detection_Config
from core.datasets.TSB_AD_U.config import TSB_AD_U_Config

dataset_config = {
    'ucr_anomaly_detection': {
        'dataset_name': 'UCR_Anomaly_Detection',
        'raw_getter_config': UCR_Anomaly_Detection_Config(
            variant_name = 'size-1000',
            grouping_file = 'designated_grouping',
            group = 'AirTemperature',
        ),
    },
    
    'tsb_ad_u': {
        'dataset_name': 'TSB_AD_U',
        'raw_getter_config': TSB_AD_U_Config(
            variant_name = 'size-200',
            grouping_file = 'random_grouping',
            group = 'random_group_1',
        ),
    },
    
}

model_config = {
    'transformer_noPatch-UCR_Anomaly_Detection': None,
    'transformer_noPatch-TSB_AD_U': None,
    
    'transformer_patchTST-UCR_Anomaly_Detection': None,
    'transformer_PatchTST-TSB_AD_U': None,
    
    ###
    # check for best then, do 2+2 attn head
    'transformer_patchTST_mpAttn-UCR_Anomaly_Detection': None,
    'transformer_patchTST_mpAttn-TSB_AD_U': None,
    
    'transformer_patchTST_mpAttn_QKWeightShare-UCR_Anomaly_Detection': None,
    'transformer_patchTST_mpAttn-QKWeightShareTSB_AD_U': None,
    ###
    
    'simple_cnn-UCR_Anomaly_Detection': None,
    'simple_cnn-TSB_AD_U': None,
    
    'matrix_profile-UCR_Anomaly_Detection': None,
    'matrix_profile-TSB_AD_U': None,
    
    'UNet-UCR_Anomaly_Detection': None,
    'UNet-TSB_AD_U': None,
}
